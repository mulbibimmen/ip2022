# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('dsu1.jpg')
res = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_CUBIC)
cv2.imwrite('res_dsu1.jpg',res)
# Out:
# True

# %%
img = cv2.imread('u303.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[50,50],[200,50],[50,200]])
pts2 = np.float32([[10,100],[200,50],[100,250]])

M = cv2.getAffineTransform(pts1,pts2)

dst = cv2.warpAffine(img,M,(cols,rows))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
# Out:
# (<AxesSubplot:title={'center':'Output'}>,
#  <matplotlib.image.AxesImage at 0x267f0f27430>,
#  Text(0.5, 1.0, 'Output'))

# %%
img = cv2.imread('u303.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[[22,2389],[1622,811],[1534,3528],[2805,1391]]])
pts2 = np.float32([[0,0],[300,0],[0,300],[300,300]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(300,300))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
