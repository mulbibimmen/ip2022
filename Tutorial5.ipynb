# %%
if x == 3:
   print ("X equals 3.")
elif x == 2:
  print ("X equals 2.")
else:
  print ("X equals something else.")

print ("This is outside the ‘if’.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bfc9d00b670f> in <module>
# ----> 1 if x == 3:
#       2    print ("X equals 3.")
#       3 elif x == 2:
#       4   print ("X equals 2.")
#       5 else:
#
# NameError: name 'x' is not defined

# %%
x = 3
while x < 5:
  print (x , "still in the loop")
  x = x+1
# Out:
# 3 still in the loop
# 4 still in the loop

# %%
x = 6
while x < 5:
  print (x,"still in the loop")
